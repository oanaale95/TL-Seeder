# %% [markdown]
# ### Intro Packages

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', 500)

# %% [markdown]
# # Datasets inspection

# %%
df_acquisitions = pd.read_csv('cb_acquisitions.csv')
df_acquisitions.head(3)
# Out:
#    id  acquisition_id acquiring_object_id acquired_object_id term_code  \
# 0   1               1                c:11               c:10       NaN
# 1   2               7                c:59               c:72      cash
# 2   3               8                c:24              c:132      cash
#
#    price_amount price_currency_code acquired_at  \
# 0    20000000.0                 USD  2007-05-30
# 1    60000000.0                 USD  2007-07-01
# 2   280000000.0                 USD  2007-05-01
#
#                                           source_url  \
# 0  http://venturebeat.com/2007/05/30/fox-interact...
# 1  http://www.techcrunch.com/2007/07/02/deal-is-c...
# 2  http://www.techcrunch.com/2007/05/30/cbs-acqui...
#
#                                   source_description           created_at  \
# 0  Fox Interactive confirms purchase of Photobuck...  2007-05-31 22:19:54
# 1    Deal is Confirmed: Google Acquired GrandCentral  2007-07-03 08:14:50
# ...

# %%
df_degrees = pd.read_csv('cb_degrees.csv')
df_degrees.head(3)
# Out:
#    id object_id degree_type             subject  \
# 0   1    p:6117         MBA                 NaN
# 1   2    p:6136          BA     English, French
# 2   3    p:6136          MS  Mass Communication
#
#                         institution graduated_at           created_at  \
# 0                               NaN          NaN  2008-02-19 03:17:36
# 1  Washington University, St. Louis   1990-01-01  2008-02-19 17:58:31
# 2                 Boston University   1992-01-01  2008-02-19 17:58:31
#
#             updated_at
# 0  2008-02-19 03:17:36
# 1  2008-02-25 00:23:55
# 2  2008-02-25 00:23:55

# %%
df_funding = pd.read_csv('cb_funding_rounds.csv', low_memory=False)
df_funding.columns
# Out:
# Index(['id', 'funding_round_id', 'object_id', 'funded_at',
#        'funding_round_type', 'funding_round_code', 'raised_amount_usd',
#        'raised_amount', 'raised_currency_code', 'pre_money_valuation_usd',
#        'pre_money_valuation', 'pre_money_currency_code',
#        'post_money_valuation_usd', 'post_money_valuation',
#        'post_money_currency_code', 'participants', 'is_first_round',
#        'is_last_round', 'source_url', 'source_description', 'created_by',
#        'created_at', 'updated_at'],
#       dtype='object')

# %%
df_relations = pd.read_csv('cb_relationships.csv', low_memory=False)
df_relations.head(50)
# Out:
#     id  relationship_id person_object_id relationship_object_id    start_at  \
# 0    1                1              p:2                    c:1         NaN
# 1    2                2              p:3                    c:1         NaN
# 2    3                3              p:4                    c:3         NaN
# 3    4                4              p:5                    c:3  2006-03-01
# 4    6                6              p:7                    c:4  2005-07-01
# 5    7                7              p:8                    c:4         NaN
# 6    8                8              p:9                    c:4         NaN
# 7    9                9             p:10                    c:5         NaN
# 8   10               10             p:11                    c:5         NaN
# 9   11               11             p:12                    c:5         NaN
# 10  12               12             p:13                    c:5         NaN
# ...

# %%
df_funds= pd.read_csv('cb_funds.csv', low_memory=False)
df_funds.head(3)
# Out:
#    id  fund_id object_id                        name   funded_at  \
# 0   1        1     f:371                 Second Fund  2008-12-16
# 1   4        4      f:17  Sequoia Israel Fourth Fund  2008-12-17
# 2   5        5     f:951                  Tenth fund  2008-08-11
#
#    raised_amount raised_currency_code  \
# 0    300000000.0                  USD
# 1    200750000.0                  USD
# 2    650000000.0                  USD
#
#                                           source_url  \
# 0  http://www.pehub.com/26194/dfj-dragon-raising-...
# 1  http://www.pehub.com/26725/sequoia-israel-rais...
# 2  http://venturebeat.com/2008/08/11/interwest-cl...
#
#                   source_description           created_at           updated_at
# 0                              peHub  2008-12-17 03:07:16  2008-12-17 03:07:16
# 1  Sequoia Israel Raises Fourth Fund  2008-12-18 22:04:42  2008-12-18 22:04:42
# 2                       Venture Beat  2008-12-31 09:47:51  2008-12-31 09:47:51

# %%
df_investments= pd.read_csv('cb_investments.csv')
df_investments.head(3)
# Out:
#    id  funding_round_id funded_object_id investor_object_id  \
# 0   1                 1              c:4                f:1
# 1   2                 1              c:4                f:2
# 2   3                 3              c:5                f:4
#
#             created_at           updated_at
# 0  2007-07-04 04:52:57  2008-02-27 23:14:29
# 1  2007-07-04 04:52:57  2008-02-27 23:14:29
# 2  2007-05-27 06:09:10  2013-06-28 20:07:23

# %%
df_ipos= pd.read_csv('cb_ipos.csv')
df_ipos.head(3)
# Out:
#    id  ipo_id object_id  valuation_amount valuation_currency_code  \
# 0   1       1    c:1654               NaN                     USD
# 1   2       2    c:1242               NaN                     USD
# 2   3       3     c:342               NaN                     USD
#
#    raised_amount raised_currency_code   public_at stock_symbol source_url  \
# 0            NaN                  USD  1980-12-19  NASDAQ:AAPL        NaN
# 1            NaN                  NaN  1986-03-13  NASDAQ:MSFT        NaN
# 2            NaN                  NaN  1969-06-09     NYSE:DIS        NaN
#
#   source_description           created_at           updated_at
# 0                NaN  2008-02-09 05:17:45  2012-04-12 04:02:59
# 1                NaN  2008-02-09 05:25:18  2010-12-11 12:39:46
# 2                NaN  2008-02-09 05:40:32  2010-12-23 08:58:16

# %%
df_milestones= pd.read_csv('cb_milestones.csv')
df_milestones.head(3)
# Out:
#    id object_id milestone_at milestone_code  \
# 0   1      c:12   2008-06-09          other
# 1   2    c:3138   2008-06-17          other
# 2   3      c:59   2008-06-18          other
#
#                                          description  \
# 0                       Survives iPhone 3G Stevenote
# 1  Twhirl announces support for Seesmic video pla...
# 2  More than 4 Billion videos viewed at Google Si...
#
#                                           source_url  \
# 0  http://www.techcrunch.com/2008/06/10/twitter-f...
# 1  http://www.inquisitr.com/1103/seesmic-now-avai...
# 2  http://www.comscore.com/press/release.asp?pres...
#
#                                   source_description           created_at  \
# 0          Twitter Fails To Fail, Community Rejoices  2008-06-18 08:14:06
# 1                    Seesmic Now Available In Twhirl  2008-06-18 08:46:28
# 2  11 Billion Videos Viewed Online in the U.S. in...  2008-06-18 08:50:24
#
#             updated_at
# 0  2008-06-18 08:14:06
# ...

# %%
df_objects= pd.read_csv('cb_objects.csv', low_memory=False)
df_objects
# Out:
#               id entity_type  entity_id parent_id  \
# 0            c:1     Company          1       NaN
# 1           c:10     Company         10       NaN
# 2          c:100     Company        100       NaN
# 3        c:10000     Company      10000       NaN
# 4        c:10001     Company      10001       NaN
# 5        c:10002     Company      10002       NaN
# 6        c:10003     Company      10003       NaN
# 7       c:100042     Company     100042       NaN
# 8        c:10005     Company      10005       NaN
# 9       c:100062     Company     100062       NaN
# 10      c:100068     Company     100068       NaN
# 11       c:10008     Company      10008       NaN
# 12       c:10009     Company      10009       NaN
# 13        c:1001     Company       1001       NaN
# 14       c:10010     Company      10010       NaN
# 15       c:10011     Company      10011       NaN
# 16       c:10012     Company      10012       NaN
# 17       c:10013     Company      10013       NaN
# ...

# %%
df_offices= pd.read_csv('cb_offices.csv')
df_offices.head(3)
# Out:
#    id object_id  office_id   description   region            address1  \
# 0   1       c:1          1           NaN  Seattle    710 - 2nd Avenue
# 1   2       c:3          3  Headquarters   SF Bay     4900 Hopyard Rd
# 2   3       c:4          4           NaN   SF Bay  135 Mississippi St
#
#      address2           city zip_code state_code country_code   latitude  \
# 0  Suite 1100        Seattle    98104         WA          USA  47.603122
# 1   Suite 310     Pleasanton    94588         CA          USA  37.692934
# 2         NaN  San Francisco    94107         CA          USA  37.764726
#
#     longitude  created_at  updated_at
# 0 -122.333253         NaN         NaN
# 1 -121.904945         NaN         NaN
# 2 -122.394523         NaN         NaN

# %%
df_people= pd.read_csv('cb_people.csv') 
df_people.head(3)
# Out:
#    id object_id first_name last_name birthplace affiliation_name
# 0   1       p:2        Ben   Elowitz        NaN        Blue Nile
# 1   2       p:3      Kevin  Flaherty        NaN         Wetpaint
# 2   3       p:4       Raju   Vegesna        NaN             Zoho

# %%
df_relationships= pd.read_csv('cb_relationships.csv')
df_relationships
# Out:
#             id  relationship_id person_object_id relationship_object_id  \
# 0            1                1              p:2                    c:1
# 1            2                2              p:3                    c:1
# 2            3                3              p:4                    c:3
# 3            4                4              p:5                    c:3
# 4            6                6              p:7                    c:4
# 5            7                7              p:8                    c:4
# 6            8                8              p:9                    c:4
# 7            9                9             p:10                    c:5
# 8           10               10             p:11                    c:5
# 9           11               11             p:12                    c:5
# 10          12               12             p:13                    c:5
# 11          13               13             p:14                    c:5
# ...

# %%
df_relationships.rename({'person_object_id': 'object_id'}, axis='columns', inplace=True)

# %% [markdown]
# ## Merge People & Degrees

# %%
#Created dataframe that merges the info
df_peep= pd.merge(df_people, df_degrees, on='object_id')
df_peep.head(5)
# Out:
#    id_x object_id first_name last_name birthplace affiliation_name   id_y  \
# 0     1       p:2        Ben   Elowitz        NaN        Blue Nile    699
# 1     1       p:2        Ben   Elowitz        NaN        Blue Nile    700
# 2     2       p:3      Kevin  Flaherty        NaN         Wetpaint    706
# 3     2       p:3      Kevin  Flaherty        NaN         Wetpaint    707
# 4     4       p:5        Ian     Wenig        NaN             Zoho  47870
#
#   degree_type                                  subject  \
# 0          BS  Electrical Engineering/Computer Science
# 1          BS                      Applied Mathematics
# 2         BBA                                      NaN
# 3         MBA                                      NaN
# 4      Degree    Advanced Business Professional Course
#
#                           institution graduated_at           created_at  \
# 0  University of California, Berkeley   1994-01-01  2008-05-06 00:05:48
# ...

# %%
#Check data types 
df_peep.dtypes
# Out:
# id_x                 int64
# object_id           object
# first_name          object
# last_name           object
# birthplace          object
# affiliation_name    object
# id_y                 int64
# degree_type         object
# subject             object
# institution         object
# graduated_at        object
# created_at          object
# updated_at          object
# dtype: object

# %%
#drop birthplace useless columns
#df_peep.drop(['birthplace','graduated_at'], axis=1, inplace= True)

# %% [markdown]
# #### Move the info per person and not for two rows

# %%
for unique_value in df_peep.object_id.unique():
    df_tmp = df_peep.loc[df_peep['object_id'] == unique_value]
    
    no_rows = df_tmp.shape[0]
    if no_rows > 1:
        print('merge rows into one')
    else:
        print('this row is unique')
    
    print(df_tmp)
    break
# Out:
# merge rows into one
#    id_x object_id first_name last_name birthplace affiliation_name  id_y  \
# 0     1       p:2        Ben   Elowitz        NaN        Blue Nile   699
# 1     1       p:2        Ben   Elowitz        NaN        Blue Nile   700
#
#   degree_type                                  subject  \
# 0          BS  Electrical Engineering/Computer Science
# 1          BS                      Applied Mathematics
#
#                           institution graduated_at           created_at  \
# 0  University of California, Berkeley   1994-01-01  2008-05-06 00:05:48
# 1  University of California, Berkeley   1994-01-01  2008-05-06 00:06:10
#
#             updated_at
# 0  2008-05-06 00:05:48
# 1  2008-05-06 00:06:10

# %%
# merge the name
df_peep['full_name'] = df_peep['first_name'] + ' ' +df_peep['last_name']

# %% [markdown]
# ### How df_people looks now

# %%
df_peep
# Out:
#           id_x object_id first_name         last_name       birthplace  \
# 0            1       p:2        Ben           Elowitz              NaN
# 1            1       p:2        Ben           Elowitz              NaN
# 2            2       p:3      Kevin          Flaherty              NaN
# 3            2       p:3      Kevin          Flaherty              NaN
# 4            4       p:5        Ian             Wenig              NaN
# 5            4       p:5        Ian             Wenig              NaN
# 6            5       p:6      Kevin              Rose      Redding, CA
# 7            5       p:6      Kevin              Rose      Redding, CA
# 8            6       p:7        Jay           Adelson      Detroit, MI
# 9            7       p:8       Owen             Byrne              NaN
# 10           7       p:8       Owen             Byrne              NaN
# 11           8       p:9        Ron        Gorodetzky              NaN
# ...

# %% [markdown]
# ## Merge Object, Offices, Milestones, Ipos

# %%
df_offices.head(3)
# Out:
#    id object_id  office_id   description   region            address1  \
# 0   1       c:1          1           NaN  Seattle    710 - 2nd Avenue
# 1   2       c:3          3  Headquarters   SF Bay     4900 Hopyard Rd
# 2   3       c:4          4           NaN   SF Bay  135 Mississippi St
#
#      address2           city zip_code state_code country_code   latitude  \
# 0  Suite 1100        Seattle    98104         WA          USA  47.603122
# 1   Suite 310     Pleasanton    94588         CA          USA  37.692934
# 2         NaN  San Francisco    94107         CA          USA  37.764726
#
#     longitude  created_at  updated_at
# 0 -122.333253         NaN         NaN
# 1 -121.904945         NaN         NaN
# 2 -122.394523         NaN         NaN

# %%
pd.options.display.max_columns = None

# %%
df_objects.head(3)
# Out:
#       id entity_type  entity_id parent_id      name normalized_name  \
# 0    c:1     Company          1       NaN  Wetpaint        wetpaint
# 1   c:10     Company         10       NaN   Flektor         flektor
# 2  c:100     Company        100       NaN     There           there
#
#            permalink category_code     status  founded_at closed_at  \
# 0  /company/wetpaint           web  operating  2005-10-17       NaN
# 1   /company/flektor   games_video   acquired         NaN       NaN
# 2     /company/there   games_video   acquired         NaN       NaN
#
#              domain             homepage_url twitter_username  \
# 0  wetpaint-inc.com  http://wetpaint-inc.com  BachelrWetpaint
# 1       flektor.com   http://www.flektor.com              NaN
# 2         there.com     http://www.there.com              NaN
#
#                                             logo_url  logo_width  logo_height  \
# 0  http://s3.amazonaws.com/crunchbase_prod_assets...       401.0         54.0
# ...

# %%
df_objects.rename(columns={"id": "object_id"}, inplace= True)

# %%
#Created dataframe that merges the info
df_companies= pd.merge(df_objects, df_offices, on= 'object_id')
df_merger= pd.merge(df_milestones, df_ipos, on= 'object_id')
df_companies = pd.merge(df_companies, df_merger, on= 'object_id')

# %%
df_companies.shape
# Out:
# (5211, 74)

# %%
df_companies.columns
# Out:
# Index(['object_id', 'entity_type', 'entity_id', 'parent_id', 'name',
#        'normalized_name', 'permalink', 'category_code', 'status', 'founded_at',
#        'closed_at', 'domain', 'homepage_url', 'twitter_username', 'logo_url',
#        'logo_width', 'logo_height', 'short_description', 'description_x',
#        'overview', 'tag_list', 'country_code_x', 'state_code_x', 'city_x',
#        'region_x', 'first_investment_at', 'last_investment_at',
#        'investment_rounds', 'invested_companies', 'first_funding_at',
#        'last_funding_at', 'funding_rounds', 'funding_total_usd',
#        'first_milestone_at', 'last_milestone_at', 'milestones',
#        'relationships', 'created_by', 'created_at_x_x', 'updated_at_x_x', 'id',
#        'office_id', 'description_y', 'region_y', 'address1', 'address2',
#        'city_y', 'zip_code', 'state_code_y', 'country_code_y', 'latitude',
#        'longitude', 'created_at_y_x', 'updated_at_y_x', 'id_x', 'milestone_at',
# ...

# %%
df_companies.head(70)
# Out:
#    object_id entity_type  entity_id parent_id              name  \
# 0   c:100844     Company     100844       NaN          Attunity
# 1    c:10106     Company      10106       NaN   Thomson Reuters
# 2    c:10222     Company      10222       NaN           Hitachi
# 3   c:104377     Company     104377       NaN      Tremor Video
# 4   c:104377     Company     104377       NaN      Tremor Video
# 5   c:104377     Company     104377       NaN      Tremor Video
# 6   c:104377     Company     104377       NaN      Tremor Video
# 7    c:10453     Company      10453       NaN          Bankrate
# 8    c:10475     Company      10475       NaN       Abbott Labs
# 9    c:10475     Company      10475       NaN       Abbott Labs
# 10   c:10545     Company      10545       NaN  LRAD Corporation
# 11   c:10545     Company      10545       NaN  LRAD Corporation
# 12   c:10545     Company      10545       NaN  LRAD Corporation
# 13   c:10545     Company      10545       NaN  LRAD Corporation
# ...

# %%
df_companies_db= pd.DataFrame([df_companies['name'].unique() , df_peep['full_name'].unique() , df_peep['affiliation_name'].unique()]).transpose()
df_companies_db.head()
# Out:
#                  0               1             2
# 0         Attunity     Ben Elowitz     Blue Nile
# 1  Thomson Reuters  Kevin Flaherty      Wetpaint
# 2          Hitachi       Ian Wenig          Zoho
# 3     Tremor Video      Kevin Rose  i/o Ventures
# 4         Bankrate     Jay Adelson          Digg

# %%
df_companies.nunique()
# Out:
# object_id                   591
# entity_type                   1
# entity_id                   591
# parent_id                     0
# name                        591
# normalized_name             591
# permalink                   591
# category_code                32
# status                        2
# founded_at                  142
# closed_at                     0
# domain                      590
# homepage_url                590
# twitter_username            348
# logo_url                    587
# logo_width                  272
# logo_height                 177
# short_description            50
# description_x               265
# overview                    590
# tag_list                    157
# country_code_x               21
# state_code_x                 35
# city_x                      294
# region_x                    151
# first_investment_at         137
# last_investment_at          132
# investment_rounds            20
# invested_companies           19
# ...

# %% [markdown]
# ## What type of info we have

# %%
pd.set_option('display.max_columns', 500)

# %%
df_companies.head(5)
# Out:
#   object_id entity_type  entity_id parent_id             name  \
# 0  c:100844     Company     100844       NaN         Attunity
# 1   c:10106     Company      10106       NaN  Thomson Reuters
# 2   c:10222     Company      10222       NaN          Hitachi
# 3  c:104377     Company     104377       NaN     Tremor Video
# 4  c:104377     Company     104377       NaN     Tremor Video
#
#    normalized_name                 permalink     category_code status  \
# 0         attunity         /company/attunity          software    ipo
# 1  thomson reuters  /company/thomson-reuters  public_relations    ipo
# 2          hitachi          /company/hitachi  public_relations    ipo
# 3     tremor video     /company/tremor-video       advertising    ipo
# 4     tremor video     /company/tremor-video       advertising    ipo
#
#    founded_at closed_at              domain               homepage_url  \
# 0         NaN       NaN        attunity.com    http://www.attunity.com
# ...

# %%
companies_info_list = list(df_companies.columns)
companies_info_list
#we need : 
companies_needed_info = ['object_id', 'entity_type', 'name', 'category_code','status', 'founded_at', 'closed_at', 'overview','country_code','state_code', 'city_x','region_x', 'first_investment_at', 'last_investment_at', 'investment_rounds', 'invested_companies', 'first_funding_at', 'last_funding_at', 'funding_rounds', 'funding_total_usd', 'first_milestone_at', 'last_milestone_at','created_by', 'created_at', 'valuation_amount', 'valuation_currency_code','raised_amount', 'raised_currency_code', 'public_at']

# %%
df_peep.head(3)
# Out:
#    id_x object_id first_name last_name birthplace affiliation_name  id_y  \
# 0     1       p:2        Ben   Elowitz        NaN        Blue Nile   699
# 1     1       p:2        Ben   Elowitz        NaN        Blue Nile   700
# 2     2       p:3      Kevin  Flaherty        NaN         Wetpaint   706
#
#   degree_type                                  subject  \
# 0          BS  Electrical Engineering/Computer Science
# 1          BS                      Applied Mathematics
# 2         BBA                                      NaN
#
#                           institution graduated_at           created_at  \
# 0  University of California, Berkeley   1994-01-01  2008-05-06 00:05:48
# 1  University of California, Berkeley   1994-01-01  2008-05-06 00:06:10
# 2   Washington University in St Louis          NaN  2008-05-07 19:40:58
#
#             updated_at       full_name
# 0  2008-05-06 00:05:48     Ben Elowitz
# 1  2008-05-06 00:06:10     Ben Elowitz
# ...

# %%
people_info_list= list(df_peep.columns)
people_needed_info = ['full_name', 'subject', 'object_id', 'relationship_object_id']

# %%
df_people= pd.merge(df_peep, df_relationships, on='object_id')

# %%
df_people
# Out:
#           id_x object_id first_name  last_name birthplace affiliation_name  \
# 0            1       p:2        Ben    Elowitz        NaN        Blue Nile
# 1            1       p:2        Ben    Elowitz        NaN        Blue Nile
# 2            1       p:2        Ben    Elowitz        NaN        Blue Nile
# 3            1       p:2        Ben    Elowitz        NaN        Blue Nile
# 4            1       p:2        Ben    Elowitz        NaN        Blue Nile
# 5            1       p:2        Ben    Elowitz        NaN        Blue Nile
# 6            1       p:2        Ben    Elowitz        NaN        Blue Nile
# 7            1       p:2        Ben    Elowitz        NaN        Blue Nile
# 8            1       p:2        Ben    Elowitz        NaN        Blue Nile
# 9            1       p:2        Ben    Elowitz        NaN        Blue Nile
# 10           1       p:2        Ben    Elowitz        NaN        Blue Nile
# ...

# %%
def keep_only_needed_info(df_tmp, list_columns):
    for element in list(df_tmp.columns):
        if element not in list_columns:
            print(element)
            df_tmp.drop([element], axis=1)

# %%
keep_only_needed_info(df_people, people_needed_info)
# Out:
# id_x
# first_name
# last_name
# birthplace
# affiliation_name
# id_y
# degree_type
# institution
# graduated_at
# created_at_x
# updated_at_x
# id
# relationship_id
# start_at
# end_at
# is_past
# sequence
# title
# created_at_y
# updated_at_y

# %%
people_needed_info
# Out:
# ['full_name', 'subject', 'object_id', 'relationship_object_id']

# %%
df_people_needed_info = df_people[people_needed_info]
df_people_needed_info
# Out:
#                full_name                                  subject object_id  \
# 0            Ben Elowitz  Electrical Engineering/Computer Science       p:2
# 1            Ben Elowitz  Electrical Engineering/Computer Science       p:2
# 2            Ben Elowitz  Electrical Engineering/Computer Science       p:2
# 3            Ben Elowitz  Electrical Engineering/Computer Science       p:2
# 4            Ben Elowitz  Electrical Engineering/Computer Science       p:2
# 5            Ben Elowitz  Electrical Engineering/Computer Science       p:2
# 6            Ben Elowitz  Electrical Engineering/Computer Science       p:2
# 7            Ben Elowitz  Electrical Engineering/Computer Science       p:2
# 8            Ben Elowitz                      Applied Mathematics       p:2
# 9            Ben Elowitz                      Applied Mathematics       p:2
# 10           Ben Elowitz                      Applied Mathematics       p:2
# ...

# %%
df_people_needed_info.to_csv('people_info.csv')
