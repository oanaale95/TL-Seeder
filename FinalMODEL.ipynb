# %%
import pandas as pd
import numpy as np

# %%
from sklearn.pipeline import Pipeline
from sklearn.pipeline import FeatureUnion
from sklearn.base import BaseEstimator, TransformerMixin

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold

from sklearn.linear_model import LogisticRegression

# Class, for use in pipelines, to select certain columns from a DataFrame and convert to a numpy array
# From A. Geron: Hands-On Machine Learning with Scikit-Learn & TensorFlow, O'Reilly, 2017
# Modified by Derek Bridge to allow for casting in the same ways as pandas.DataFrame.astype
class DataFrameSelector(BaseEstimator, TransformerMixin):
    def __init__(self, attribute_names, dtype=None):
        self.attribute_names = attribute_names
        self.dtype = dtype
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        X_selected = X[self.attribute_names]
        if self.dtype:
            return X_selected.astype(self.dtype).values
        return X_selected.values
    
# Class, for use in pipelines, to binarize nominal-valued features (while avoiding the dummy variabe trap)
# By Derek Bridge, 2017
class FeatureBinarizer(BaseEstimator, TransformerMixin):
    def __init__(self, features_values):
        self.features_values = features_values
        self.num_features = len(features_values)
        self.labelencodings = [LabelEncoder().fit(feature_values) for feature_values in features_values]
        self.onehotencoder = OneHotEncoder(sparse=False,
            n_values=[len(feature_values) for feature_values in features_values])
        self.last_indexes = np.cumsum([len(feature_values) - 1 for feature_values in self.features_values])
    def fit(self, X, y=None):
        for i in range(0, self.num_features):
            X[:, i] = self.labelencodings[i].transform(X[:, i])
        return self.onehotencoder.fit(X)
    def transform(self, X, y=None):
        for i in range(0, self.num_features):
            X[:, i] = self.labelencodings[i].transform(X[:, i])
        onehotencoded = self.onehotencoder.transform(X)
        return np.delete(onehotencoded, self.last_indexes, axis=1)
    def fit_transform(self, X, y=None):
        onehotencoded = self.fit(X).transform(X)
        return np.delete(onehotencoded, self.last_indexes, axis=1)
    def get_params(self, deep=True):
        return {"features_values" : self.features_values}
    def set_params(self, **parameters):
        for parameter, value in parameters.items():
            self.setattr(parameter, value)
        return self

# %%
pd.set_option('display.max_columns', None)

# %%
def get_nan_values_for_column(df, column_name):
    return df[column_name].isna().sum()

# %%
def drop_nan_values_from_columns(df, column_names_list):
    '''
    This function removes all rows, where at least one column a row,
    from the list 'column_names_list', contains a NaN value
    '''
    df_tmp = df.dropna(subset=column_names_list)
    df_tmp.reset_index(drop=True, inplace=True)
    
    return df_tmp

# %%
df = pd.read_csv('companies.csv', low_memory=False)
df
# Out:
#          acquisition_id relationship_object_id  price_amount  \
# 0                   209                   c:59  3.100000e+09
# 1                   209                   c:59  3.100000e+09
# 2                   209                   c:59  3.100000e+09
# 3                   209                   c:59  3.100000e+09
# 4                   209                   c:59  3.100000e+09
# ...                 ...                    ...           ...
# 7210973            4521                 c:3246           NaN
# 7210974            4521                 c:3246           NaN
# 7210975            4521                 c:3246           NaN
# 7210976            4521                 c:3246           NaN
# 7210977            4521                 c:3246           NaN
#
#         price_currency_code acquired_at           full_name  \
# 0                       USD  2008-03-11       Brian Kennish
# 1                       USD  2008-03-11       Brian Kennish
# 2                       USD  2008-03-11       Brian Kennish
# 3                       USD  2008-03-11       Brian Kennish
# 4                       USD  2008-03-11       Brian Kennish
# ...                     ...         ...                 ...
# 7210973                 USD  2006-09-06       Michael Klett
# 7210974                 USD  2006-09-06      Michael Lipton
# 7210975                 USD  2006-09-06       Blair Hankins
# 7210976                 USD  2006-09-06  Shanker Ramamurthy
# 7210977                 USD  2006-09-06         Karen Riley
#
#                                 subject  Aquired entity_type  entity_id  \
# 0                                   NaN    False     Company         59
# 1                                   NaN    False     Company         59
# 2                                   NaN    False     Company         59
# 3                                   NaN    False     Company         59
# 4                                   NaN    False     Company         59
# ...                                 ...      ...         ...        ...
# 7210973            Computer Engineering    False     Company       3246
# 7210974  Computer Science & Engineering    False     Company       3246
# 7210975                     Mathematics    False     Company       3246
# 7210976            Innformation Science    False     Company       3246
# 7210977                             NaN    False     Company       3246
#
#         normalized_name category_code status  founded_at closed_at  \
# 0                google        search    ipo  1998-09-07       NaN
# 1                google        search    ipo  1998-09-07       NaN
# 2                google        search    ipo  1998-09-07       NaN
# 3                google        search    ipo  1998-09-07       NaN
# 4                google        search    ipo  1998-09-07       NaN
# ...                 ...           ...    ...         ...       ...
# 7210973             ibm      software    ipo         NaN       NaN
# 7210974             ibm      software    ipo         NaN       NaN
# 7210975             ibm      software    ipo         NaN       NaN
# 7210976             ibm      software    ipo         NaN       NaN
# 7210977             ibm      software    ipo         NaN       NaN
#
#                homepage_url country_code state_code_x         city_x  \
# 0         http://google.com          USA           CA  Mountain View
# 1         http://google.com          USA           CA  Mountain View
# 2         http://google.com          USA           CA  Mountain View
# 3         http://google.com          USA           CA  Mountain View
# 4         http://google.com          USA           CA  Mountain View
# ...                     ...          ...          ...            ...
# 7210973  http://www.ibm.com          USA           NY         Armonk
# 7210974  http://www.ibm.com          USA           NY         Armonk
# 7210975  http://www.ibm.com          USA           NY         Armonk
# 7210976  http://www.ibm.com          USA           NY         Armonk
# 7210977  http://www.ibm.com          USA           NY         Armonk
#
#            region first_investment_at last_investment_at  investment_rounds  \
# 0          SF Bay          2004-06-18         2013-05-01               29.0
# 1          SF Bay          2004-06-18         2013-05-01               29.0
# 2          SF Bay          2004-06-18         2013-05-01               29.0
# 3          SF Bay          2004-06-18         2013-05-01               29.0
# 4          SF Bay          2004-06-18         2013-05-01               29.0
# ...           ...                 ...                ...                ...
# 7210973  New York          2000-08-28         2008-03-25                2.0
# 7210974  New York          2000-08-28         2008-03-25                2.0
# 7210975  New York          2000-08-28         2008-03-25                2.0
# 7210976  New York          2000-08-28         2008-03-25                2.0
# 7210977  New York          2000-08-28         2008-03-25                2.0
#
#          invested_companies first_funding_at last_funding_at  funding_rounds  \
# 0                      26.0       1998-08-01      1999-06-07             2.0
# 1                      26.0       1998-08-01      1999-06-07             2.0
# 2                      26.0       1998-08-01      1999-06-07             2.0
# 3                      26.0       1998-08-01      1999-06-07             2.0
# 4                      26.0       1998-08-01      1999-06-07             2.0
# ...                     ...              ...             ...             ...
# 7210973                 2.0              NaN             NaN             NaN
# 7210974                 2.0              NaN             NaN             NaN
# 7210975                 2.0              NaN             NaN             NaN
# 7210976                 2.0              NaN             NaN             NaN
# 7210977                 2.0              NaN             NaN             NaN
#
#          funding_total_usd  relationships           description_y    city_y  \
# 0               25100000.0         1046.0           Google Mexico    Mexico
# 1               25100000.0         1046.0            Google Haifa     Haifa
# 2               25100000.0         1046.0         Google Tel Aviv  Tel-Aviv
# 3               25100000.0         1046.0         Google Istanbul  Istanbul
# 4               25100000.0         1046.0            Google Dubai     Dubai
# ...                    ...            ...                     ...       ...
# 7210973                NaN          870.0  Corporate Headquarters    Armonk
# 7210974                NaN          870.0  Corporate Headquarters    Armonk
# 7210975                NaN          870.0  Corporate Headquarters    Armonk
# 7210976                NaN          870.0  Corporate Headquarters    Armonk
# 7210977                NaN          870.0  Corporate Headquarters    Armonk
#
#         zip_code   latitude  longitude
# 0           1100  19.507519 -99.030156
# 1          31905        NaN        NaN
# 2          66183        NaN        NaN
# 3          34394        NaN        NaN
# 4              1        NaN        NaN
# ...          ...        ...        ...
# 7210973    10504  41.109534 -73.723999
# 7210974    10504  41.109534 -73.723999
# 7210975    10504  41.109534 -73.723999
# 7210976    10504  41.109534 -73.723999
# 7210977    10504  41.109534 -73.723999
#
# [7210978 rows x 34 columns]

# %%
# print all columns and their unique values
for c in df.columns:
    print(c + " - " + str(df[c].unique()))
# Out:
# acquisition_id - [ 209  263  273 ... 4519 4520 4521]
# relationship_object_id - ['c:59' 'c:24' 'c:212' 'c:227' 'c:5' 'c:318' 'c:20' 'c:342' 'c:349'
#  'c:355' 'c:351' 'c:307' 'c:29' 'c:541' 'c:568' 'c:570' 'c:317' 'c:583'
#  'c:584' 'c:590' 'c:25' 'c:622' 'c:13171' 'c:665' 'c:674' 'c:694' 'c:156'
#  'c:754' 'c:823' 'c:826' 'c:838' 'c:840' 'c:845' 'c:851' 'c:988' 'c:1035'
#  'c:45' 'c:1246' 'c:489' 'c:1335' 'c:1354' 'c:1081' 'c:396' 'c:350'
#  'c:1242' 'c:1727' 'c:1438' 'c:1504' 'c:608' 'c:1735' 'c:2042' 'c:2050'
#  'c:2272' 'c:2312' 'c:2358' 'c:2381' 'c:2602' 'c:2720' 'c:2758' 'c:2778'
#  'c:191' 'c:2175' 'c:760' 'c:2881' 'c:966' 'c:1873' 'c:3063' 'c:3104'
#  'c:3165' 'c:3253' 'c:3316' 'c:2537' 'c:3619' 'c:757' 'c:4010' 'c:4199'
#  'c:4247' 'c:308' 'c:4272' 'c:3754' 'c:304' 'c:4797' 'c:4818' 'c:2680'
#  'c:4845' 'c:46' 'c:424' 'c:5027' 'c:5059' 'c:5160' 'c:5396' 'c:4175'
#  'c:5471' 'c:1895' 'c:5546' 'c:5548' 'c:5564' 'c:5622' 'c:250' 'c:1663'
#  'c:3526' 'c:1654' 'c:475' 'c:5744' 'c:5807' 'c:5837' 'c:1926' 'c:6020'
#  'c:2825' 'c:647' 'c:6082' 'c:256' 'c:1400' 'c:2345' 'c:6478' 'c:2394'
#  'c:3320' 'c:6674' 'c:149' 'c:6858' 'c:2903' 'c:7169' 'c:85' 'c:4138'
#  'c:7570' 'c:3277' 'c:3855' 'c:7769' 'c:7682' 'c:390' 'c:12' 'c:6812'
# subject - [nan 'Computer Science'
#  'Cognitive Psychology, Piano Performance, Business, Computer Science' ...
#  'Farmer School of Business; Finance' 'Management/Finance'
#  'Energy Efficiency, Renewable Energy and Sustainable Development']
# Aquired - [False]
# entity_type - ['Company']
# entity_id - [   59    24   212   227     5   318    20   342   349   355   351   307
#     29   541   568   570   317   583   584   590    25   622 13171   665
#    674   694   156   754   823   826   838   840   845   851   988  1035
#     45  1246   489  1335  1354  1081   396   350  1242  1727  1438  1504
#    608  1735  2042  2050  2272  2312  2358  2381  2602  2720  2758  2778
#    191  2175   760  2881   966  1873  3063  3104  3165  3253  3316  2537
#   3619   757  4010  4199  4247   308  4272  3754   304  4797  4818  2680
#   4845    46   424  5027  5059  5160  5396  4175  5471  1895  5546  5548
#   5564  5622   250  1663  3526  1654   475  5744  5807  5837  1926  6020
#   2825   647  6082   256  1400  2345  6478  2394  3320  6674   149  6858
#   2903  7169    85  4138  7570  3277  3855  7769  7682   390    12  6812
#   8488 25732  8661  8613  8763  1915  5107  9212  9241  9262  8801   297
#     31    28   565 10322 10453  3407 11004  7056  1639 11342   687  1080
#    163  3147  9931  1916  3396    34 11837  9489  7563  2695 12357 10119
#  12623  4568  3161  2989  5473 13217  3555  3654 13324 13510  6757   567
#    283  5182  3275  3246]
# normalized_name - ['google' 'cbs' 'scripps networks interactive' 'sk telecom' 'facebook'
#  'cond' 'ebay' 'the walt disney company' 'citysearch' 'hewlett packard'
#  'aol' 'forbes' 'yahoo' 'nielsen' 'techtarget' 'e w scripps' 'amazon'
#  'cendant' 'united online' 'at t' 'viacom' 'vivendi universal' 'hi media'
#  'itv' 'marchex' 'virgin usa' 'thefind' 'incisive media' 'nokia'
#  'fisher communications' 'rakuten' 'valueclick' 'real networks'
#  'electronic arts' 'echostar' 'msnbc' 'hearst' 'american greetings'
#  'datran media' 'thestreet' 'discovery communications' 'platial' 'news'
#  'iac' 'microsoft' 'netapp' 'shutterfly' 'liberty media' 'adknowledge'
#  'monster' 'b5media' 'avid life media' 'smalltown' 'homeaway'
#  'liveuniverse' 'renren' 'dell' 'xo group' 'vector' 'mzinga' 'spot runner'
#  'experian' 'demand media' 'gazprom media' 'emc' 'visible measures'
#  'taylor nelson sofres' 'friendfinder networks' 'peer 1 hosting' 'entriq'
#  'bmc software' 'intuit' 'live current media' 'jive software'
#  'lbi international' 'meredith' 'unitedlayer' 'truphone' 'trellian'
#  'forrester research' 'sony' 'cox enterprises' 'hoovers' 'oracle'
#  'melbourne it' 'strands labs' 'akamai technologies' 'supportsoft'
#  'mediresource' 'dotmobi' 'oleole' 'comcast' 'vodafone' 'current media'
#  'geary interactive' 'hellman friedman' 'curl' 'yandex' 'new york times'
#  'a123 systems' 'responsys' 'apple' 'kit digital' 'accenture' 'iwin'
#  'intergraphicdesigns' 'comscore' 'intelius' 'reuters' 'mylife'
#  'pageup people' 'netsuite' 'collective media' 'whitepages' 'globalscape'
#  'coverity' 'symantec' 'meetic' 'glam media' 'insideview' 'satmetrix'
#  'ipc media' 'popsugar' 'progress software' 'mediastay' 'buongiorno'
#  'webmd' 'toro development' 'xandros' 'echo' 'twitter' 'get holding nv'
#  'snipitron' 'spinmedia' 'brocade communications systems' 'xavier media'
#  'openlink software' 'motorola solutions' 'espn' 'acm tech' 'craveonline'
#  'vantage media' 'primaccess technologies' 'domedia' 'technorati' 'cisco'
#  'active network' 'crisp thinking' 'bankrate' 'broadsoft' 'fotodesk'
#  'namemedia' 'deem' 'auctiva' 'myheritage' 'automattic' 'cafe press'
#  'sharethis' 'procera networks' 'general electric' 'adconion media group'
#  'addthis' 'familylink' 'royaltyshare' 'red hat' 'hollywood' 'gotgame'
#  'wpp' 'publicis groupe' 'webtrends' 'rackspace' 'logitech'
#  'nuance communications' 'centro' 'babbel' 'perfect market' 'webfreedom'
#  'populis' 'barracuda networks' 'tubemogul' 'adobe systems' 'autodesk'
#  'sandisk' 'ibm']
# category_code - ['search' 'news' 'web' 'social' 'games_video' 'enterprise' 'ecommerce'
#  'mobile' 'advertising' 'public_relations' 'hardware' 'finance'
#  'network_hosting' 'software' 'travel' nan 'other' 'consulting' 'nanotech'
#  'security' 'music' 'education']
# status - ['ipo' 'operating' 'closed']
# founded_at - ['1998-09-07' '1986-01-01' '1994-01-01' '1984-03-19' '2004-02-01'
#  '2007-07-01' '1995-09-01' '1923-10-16' '1995-01-01' '1939-01-01'
#  '1985-05-24' '2007-08-01' '1922-01-01' '1999-01-01' nan '2000-09-20'
#  '1971-01-01' '1981-01-01' '1996-01-01' '2000-01-01' '2001-01-01'
#  '2006-10-01' '1910-01-01' '1997-02-07' '1998-01-01' '1982-01-01'
#  '1980-01-01' '2005-09-01' '1906-01-01' '1985-06-17' '1995-08-01'
#  '1974-04-04' '1992-01-01' '1999-09-01' '2004-01-01' '2005-06-01'
#  '2005-01-15' '2005-02-01' '2005-01-01' '2002-01-01' '1984-01-01'
#  '1997-01-01' '2007-01-01' '2006-06-01' '1998-01-21' '1979-01-01'
#  '1980-09-19' '1983-01-01' '2001-02-07' '1902-01-01' '2006-01-01'
#  '1946-01-01' '1990-01-01' '1977-01-01' '2003-10-01' '1998-08-01'
#  '1996-06-16' '2006-12-01' '1963-01-01' '1997-09-23' '1976-04-01'
#  '2008-01-01' '2001-08-01' '2002-08-01' '1999-08-01' '2003-01-01'
#  '2002-01-17' '1997-10-01' '1987-10-14' '1997-05-01' '2003-09-01'
#  '2006-04-01' '2007-03-01' '2006-03-21' '2005-03-01' '1996-12-03'
#  '1928-01-01' '1979-09-07' '2007-03-07' '2007-05-30' '2002-06-01'
#  '2005-11-20' '1993-01-01' '1998-09-01' '2005-07-01' '1999-10-01'
#  '2008-08-21' '2006-03-01' '1926-01-01' '2001-10-15' '2004-08-01'
#  '2006-11-01' '1982-12-01' '1988-01-01']
# closed_at - [nan '2010-03-01' '2010-01-04' '2013-08-20' '2009-12-23']
# homepage_url - ['http://google.com' nan 'http://www.scrippsnetworks.com'
#  'http://www.sktelecom.com' 'http://facebook.com'
#  'http://www.ipcmedia.com' 'http://www.popsugar.com'
#  'http://www.progress.com' 'http://mediastay.com'
#  'http://www.buongiorno.com' 'http://www.webmd.com'
#  'http://www.toro-intl.com' 'http://www.xandros.com'
#  'http://www.aboutecho.com' 'http://twitter.com'
#  'http://www.getholdingnv.com' 'http://www.snipitron.com'
#  'http://www.spinmedia.com' 'http://www.brocade.com'
#  'http://www.xaviermedia.com' 'http://www.openlinksw.com'
#  'http://www.motorolasolutions.com' 'http://www.espn.com'
#  'http://www.acmtech.it' 'http://www.craveonlinemedia.com'
#  'http://www.vantagemedia.com' 'http://www.primaccess.com'
#  'http://domedia.com' 'http://technoratimedia.com' 'http://www.cisco.com'
#  'http://www.ACTIVEnetwork.com' 'http://www.crispthinking.com'
#  'http://bankrate.com' 'http://www.broadsoft.com'
#  'http://www.fotodesk.com' 'http://www.namemedia.com'
#  'http://www.deem.com' 'http://www.auctiva.com'
#  'http://www.myheritage.com' 'http://automattic.com'
#  'http://www.cafepress.com' 'http://sharethis.com'
#  'http://www.proceranetworks.com' 'http://www.ge.com'
#  'http://www.adconion.com' 'http://www.addthis.com'
#  'http://www.familylink.com' 'http://royaltyshare.com'
#  'http://www.redhat.com' 'http://www.hollywood.com'
#  'http://www.gotgame.com' 'http://www.wpp.com'
#  'http://www.publicisgroupe.com' 'http://www.webtrends.com'
#  'http://www.rackspace.com' 'http://logitech.com' 'http://www.nuance.com'
#  'http://www.centro.net' 'http://www.babbel.com'
#  'http://www.perfectmarket.com' 'http://webfreedom.co.nz'
#  'http://www.populis.com' 'https://www.barracuda.com'
#  'http://www.tubemogul.com' 'http://www.adobe.com'
#  'http://www.autodesk.com' 'http://www.sandisk.com' 'http://www.ibm.com']
# country_code - ['USA' 'KOR' 'FRA' 'GBR' 'FIN' 'JPN' 'CAN' 'CHN' 'RUS' 'MYS' 'SWE' 'AUS'
#  'IRL' 'CZE' 'CRI' 'ITA' 'HKG' 'NLD' 'IND' 'CHE' 'ISR' 'DEU' 'NZL']
# state_code_x - ['CA' 'TN' nan 'NY' 'MA' 'OH' 'WA' 'TX' 'CO' 'NJ' 'OR' 'MO' 'FL' 'IA' 'GA'
#  'PA' 'VA' 'IL' 'MD' 'CT' 'UT' 'NC']
# city_x - ['Mountain View' nan 'Knoxville' 'Seoul' 'Menlo Park' 'New York'
#  'San Jose' 'Burbank' 'West Hollywood' 'Palo Alto' 'Sunnyvale' 'Newton'
#  'Cincinnati' 'Seattle' 'Woodland Hills' 'Dallas' 'London' 'Tokyo'
#  'Redwood City' 'Englewood' 'Secaucus' 'Portland' 'Redmond' 'Kansas City'
#  'Toronto, ON' 'Toronto' 'San Mateo' 'Austin' 'Beijing' 'Round Rock'
#  'San Francisco' 'Burlington' 'Los Angeles' 'Costa Mesa' 'Santa Monica'
#  'Saint-Petersburg' 'Hopkinton' 'Boston' 'Boca Raton' 'Vancouver'
#  'Carlsbad' 'Houston' 'Vancouver, BC' 'Stockholm' 'Des Moines' 'Beaumaris'
#  'Cambridge' 'San Diego' 'Atlanta' 'Melbourne' 'Dublin' 'Beverly Hills'
#  'Philadelphia' 'Berkshire' 'Moscow' 'Watertown' 'San Bruno' 'Cupertino'
#  'Prague' 'Tibás, San José' 'Reston' 'Bellevue' 'Melbourne, VIC'
#  'San Antonio' 'Boulogne-Billancourt' 'Brisbane' 'Bedford'
#  'Levallois Perret' 'Milan' 'San francisco' 'Zaandijk' 'Chicago'
#  'Hollywood' 'Vaja' 'Schaumburg' 'Cuneo' 'El Segundo' 'Hyderabad'
#  'Columbus' 'Leeds' 'North Palm Beach' 'Gaithersburg' 'Basel' 'Waltham'
#  'Chico' 'Or Yehuda' 'Fremont' 'Fairfield' 'Vienna' 'Provo' 'Raleigh'
#  'Paris' 'Berlin' 'Pasadena' 'Hamilton' 'Dublin 4' 'Campbell' 'Emeryville'
#  'San Rafael' 'Milpitas' 'Armonk']
# region - ['SF Bay' 'California - Other' 'Knoxville' 'Seoul' 'New York'
#  'Los Angeles' 'Boston' 'Cincinnati' 'Seattle' 'TBD' 'Dallas'
#  'France - Other' 'London' 'Finland - Other' 'Tokyo' 'Denver' 'Secaucus'
#  'Portland' 'Kansas City' 'Toronto' 'Austin' 'Beijing' 'Saint Petersburg'
#  'Palm Beach' 'Vancouver' 'San Diego' 'Houston' 'Stockholm' 'Des Moines'
#  'Beaumaris' 'Atlanta' 'Melbourne' 'Dublin' 'Philadelphia' 'Berkshire'
#  'Moscow' 'Prague' 'Tibás' 'Washington DC' 'San Antonio' 'Paris'
#  'Levallois Perret' 'Milan' 'Hong Kong - Other' 'Zaandijk' 'Chicago'
#  'Vaja' 'Cuneo' 'Hyderabad' 'Columbus' 'Leeds' 'Basel' 'Chico' 'Or Yehuda'
#  'Fairfield' 'Salt Lake City' 'Raleigh-Durham' 'Berlin' 'Hamilton']
# first_investment_at - ['2004-06-18' '2006-10-01' nan '2008-04-03' '2008-12-01' '2007-10-23'
#  '2004-01-22' '2009-04-30' '2010-03-08' '2006-03-01' '1996-01-01'
#  '1998-01-01' '2013-02-01' '2010-11-08' '2005-04-01' '2006-06-01'
#  '2006-12-01' '2005-08-01' '2008-03-03' '2004-01-01' '2011-09-08'
#  '2006-10-30' '2009-12-14' '2005-07-06' '2008-01-01' '2008-04-24'
#  '2007-01-01' '2005-11-01' '1987-06-16' '2005-04-17' '2008-09-03'
#  '2008-02-29' '2013-03-27' '2007-06-05' '2013-06-27' '2002-09-16'
#  '2011-02-17' '2006-04-01' '2007-06-18' '2008-08-06' '2010-09-27'
#  '2010-05-01' '2009-10-20' '1995-11-30' '2010-01-11' '2005-04-14'
#  '2008-06-01' '2005-05-05' '1998-05-01' '2007-09-10' '2009-06-05'
#  '2010-06-28' '2006-02-15' '2004-07-26' '2003-11-17' '2013-07-16'
#  '2007-03-21' '2012-08-20' '2013-03-07' '2007-03-22' '2009-09-30'
#  '2010-04-07' '2000-08-28']
#  1.630e+02 3.400e+01 6.250e+02 2.300e+01 8.400e+01 9.700e+01 6.100e+01
#  2.400e+01 1.000e+00 8.000e+01 3.100e+01 4.690e+02 4.730e+02 3.200e+01
#  1.830e+02 4.300e+01 2.540e+02 5.470e+02 2.800e+01 3.700e+01 2.750e+02
#  7.000e+01 6.000e+01 1.950e+02 7.600e+01 8.700e+02]
# description_y - ['Google Mexico' 'Google Haifa' 'Google Tel Aviv' 'Google Istanbul'
#  'Google Dubai' 'Google Headquarters' 'Google Ann Arbor' 'Google Atlanta'
#  'Google Austin' 'Google Boulder' 'Google Cambridge' 'Google Chicago'
#  'Google Coppell' 'Google Dallas' 'Google Denver' 'Google Detroit'
#  'Google Irvine' 'Google Kirkland' 'Google New York' 'Google Phoenix'
#  'Google Pittsburgh' 'Google San Francisco' 'Google Santa Monica'
#  'Google Seattle' 'Google Washington DC' 'Google Melbourne'
#  'Google Sydney' 'Google Beijing' 'Google Guangzhou' 'Google Shanghai'
#  'Google Hong Kong' 'Google Bangalore' 'Google Delhi'
#  'Google Delhi (Honeybee)' 'Google Hyderabad' 'Google Mumbai'
#  'Google Japan Headquarters' 'Google Osaka' 'Google Seoul'
#  'Google Singapore' 'Google Taipei' 'Google Aarhus' 'Google Copenhagen'
#  'Google Helsinki' 'Google Paris' 'Google Hamburg' 'Google Dublin'
#  'Google Italy' 'Google Amsterdam' 'Google Oslo' 'Google Trondheim'
#  'Google Kraków' 'Google Wrocław' 'Google Moscow' 'Google St. Petersburg'
#  'Google Madrid' 'Google Luleå Sweden' 'Google Stockholm' 'Google Zürich'
#  'Google London' 'Google Manchester' 'Google Montreal' 'Google Toronto'
#  'Google Waterloo' 'Google Buenos Aires' 'Google Sao Paulo' nan
#  'Headquarters' 'Europe HQ' 'New York' 'HP Labs' 'HQ'
#  'Global headquarters' 'Corporate Headquarters' 'headquarter'
#  'Headquarter' 'German Office' 'World Headquarters'
#  'Boise Development Center' 'Adknowledge New York'
#  'Adknowledge San Francisco' 'Adknowledge Fort Myers'
#  'Adknowledge Toronto' 'Adknowledge UK' 'Adknowledge Germany'
#  'Adknowledge France' 'Adknowledge China' 'Head Office' 'San Diego'
#  'Palo Alto HQ' 'Frankfurt Office' 'Boulder Office' 'Portland Office'
#  'Israel R&D Center' 'San Francisco' 'Los Angeles' 'Tru UK / Head Office'
#  'Tru Americas' 'Tru Australia' 'Tru Spain' 'Tru Netherlands'
#  'Tru Asia-Pac' 'dotMobi HQ' 'One Comcast Center' 'main office'
#  'San Diego Office' 'Office in St. Petersburg' 'Office in Ekaterinburg'
#  'Office in Novosibirsk' 'Office in Odessa' 'Office in Kiev'
#  'Office in Simferopol' 'Office in California' 'Office in Europe'
#  'New York Office' 'Corporate HQ in Prague' 'London Office'
#  'Melbourne Office' 'Stockholm Office' 'Buenos Aires Office'
#  'Cairo Office' 'Singapore Office' 'Toronto Office' 'Dubai Office'
#  'Southern California' 'Northern California' 'Sales Office'
#  'Tech & Dev Office' 'Symantec Sydney' 'Global Headquarters'
#  'European Headquarters' 'India - Trivandrum' 'India - Bangalore'
#  'Atlanta, Georgia' 'San Francisco Office' 'Los Angeles Office'
#  'Chicago Office' 'MEDIASTAY SAS' 'MEDIASTAY NORTH AMERICA' 'Argentina'
#  'Australia' 'Austria' 'Belgium e Netherlands' 'Brasil' 'Finland' 'France'
#  'Germany' 'Greece' 'Hong Kong' 'India' 'Ireland' 'Mexico' 'Nigeria'
#  'Norway' 'Portugal' 'Russia' 'Spain' 'South Africa' 'Switzerland'
#  'Turkey' 'UK' 'USA' 'R&D, Global operation' 'Europe regional operatoin'
#  'Europe R&D, Delivery' 'Holding' 'Office' 'Marketing & Sales'
#  'Asia Pacific Headquarters' 'R&D' 'USA Office' 'UK Office'
#  'Disney Interactive' 'Scottsdale Office' 'Software Engineering'
#  'Scottsdale, Arizona' 'Bangalore India Office' 'Secaucus, New Jersey'
#  'Automattic Lounge' 'U.S. Headquarters' 'Asia/Pacific Headquarters'
#  'Japan Office' 'China/N. Asian Office' 'HQ - Virginia' 'Michigan Office'
#  'FamilyLink.com, Inc.' 'S. America Headquarters' 'NYC' 'Florida'
#  'GotGame HQ' 'American Headquarters' 'Logitech Audio Group'
#  'Remote Controls Group' 'Streaming Media Systems' 'East' 'South' 'West'
#  'Lesson Nine GmbH' 'WebSpring NZ' 'GoAdv Dublin' 'GoAdv Rome'
#  'Company Headquarters']
# city_y - ['Mexico' 'Haifa' 'Tel-Aviv' 'Istanbul' 'Dubai' 'Mountain View'
#  'Ann Arbor' 'Atlanta' 'Austin' 'Boulder' 'Cambridge' 'Chicago' 'Coppell'
#  'Dallas' 'Denver' 'Birmingham' 'Irvine' 'Kirkland' 'New York' 'Tempe'
#  'Pittsburgh' 'San Francisco' 'Santa Monica' 'Seattle' 'Washington'
#  'Melbourne' 'Sydney' 'Beijing' 'Guangzhou' 'Shanghai' 'Central'
#  'Bangalore' 'Gurgaon' 'New Delhi' 'Hyderabad' 'Mumbai' 'Tokyo' 'Osaka'
#  'Seoul' 'Singapore' 'Taipei' nan 'Helsinki' 'Paris' 'Hamburg' 'Dublin'
#  'Milan' 'Amsterdam' 'Oslo' 'Trondheim' 'Kraków' 'Wroclaw' 'Moscow'
#  'St. Petersburg' 'Madrid' 'Luleå' 'Stockholm' 'Zürich' 'London'
#  'Manchester' 'Montreal' 'Toronto' 'Waterloo' 'Buenos Aires' 'Sao Paulo'
#  'Knoxville' 'Menlo Park' 'San Jose' 'Burbank' 'West Hollywood'
#  'Palo Alto' 'Sunnyvale' 'Newton' 'Cincinnati' 'Woodland Hills'
#  'Unterhaching' 'Redwood City' 'Englewood' 'Secaucus' 'Portland' 'Redmond'
#  'Boise' 'Kansas City' 'Fort Myers' 'Covent Garden, London' 'Munich'
#  'Toronto, ON' 'San Mateo' 'Round Rock' 'Burlington' 'Los Angeles'
#  'Costa Mesa' 'Bellevue' 'Saint-Petersburg' 'Hopkinton' 'Boston'
#  'Boca Raton' 'Vancouver' 'Carlsbad' 'Houston' 'San Diego' 'Vancouver, BC'
#  'Frankfurt am Main' 'Or Yehuda' 'Des Moines' 'Bilthoven' 'Beaumaris'
#  'Corvalis' 'Barcelona' 'Beverly Hills' 'Philadelphia' 'Berkshire'
#  'Saint Petersburg' 'Ekaterinburg' 'Novosibirsk' 'Odessa' 'Kiev'
#  'Simferopol' 'Luzern' 'Watertown' 'San Bruno' 'Cupertino' 'Prague'
#  'Windsor, Victoria' 'Ciudad de Buenos Aires' 'Maspero, Cairo'
#  'Mississauga, Ontario' 'Edinburgh' 'Toronto, Ontario' 'Tibás, San José'
#  'Reston' 'tulsa' 'Los Altos' 'Melbourne, VIC' 'Johns Creek'
#  "Jing'an District, Shanghai" 'Frisco' 'Southfield' 'Charlestown'
#  'Fort Worth' 'San Antonio' 'Boulogne-Billancourt' 'Brisbane'
#  'Marathalli ORR, Deverabeesanahalli,' 'Culver City' 'Bedford'
#  'Levallois Perret' 'Parma' 'North Sydney NSW' 'Wien' 'The Hague'
#  'São Paulo' 'Berlin' 'Athens' 'Hong Kong' 'México D.F.' 'Lagos' 'Lisbon'
#  'Cape Town' 'Buchs' 'Los Gatos' 'Frankfurt' 'Ottawa' 'Poznan'
#  'San francisco' 'Zaandijk' 'Willemstad, Curacao' 'Aliso Viejo'
#  'Hollywood' 'Geneva' 'Vaja' 'Miami' 'Croydon, Surrey' 'Schaumburg'
#  'Cuneo' 'Scottsdale' 'El Segundo' 'Columbus' 'Leeds' 'North Palm Beach'
#  'Gaithersburg' 'Basel' 'Trivandrum' 'Waltham' 'Scotts' 'Chico' 'Fremont'
#  '432 40 Varberg' 'Minato-ku Tokyo' 'Fairfield' 'M' 'Vienna' 'Troy'
#  'Provo' 'Raleigh' 'Dublin 2' 'Mississauga' 'Pasadena' 'Hamilton'
#  'Dublin 4' 'Rome' 'Campbell' 'Fresno' 'Hampshire' 'Sydney, NSW'
#  'Emeryville' 'San Rafael' 'Milpitas' 'Armonk']
# zip_code - ['1100' '31905' '66183' '34394' '1' nan '48104' '30309' '78731' '80302'
#  '02142' '60610' '75019' '75219' '80237' '48009' '92612' '98033' '10011'
#  '85281' '15213' '94105' '90401' '98103' '20005' '3000' '2000' '100084'
#  '510620' '200001' '560 001' '122002' '110044' '500 081' '400 025'
#  '150-8512' '550-0002' '135 984' '048583' '110' '75002' '20354' '4'
#  '20122' '1082' 'N-0164' '7014' '31-123' '50-265' '115035' '191186'
#  '28020' '977 75' '111 21' '8002' 'SW1W 9TQ' 'M1 5AN' 'H3B4W5' 'M5J 2S1'
#  'N2L 6R6' 'C1107AAH' '04538-132' '37950' '94025' '10017' '94025.0'
#  '10017.0' '10036-6518' '95125' '91521' '90069' '94304-1185' '94304'
#  '10003' '94089' '94089.0' '10004.0' '2466.0' '45202.0' '98144.0'
#  '91367.0' '10036' 'Paris, 75002' '98101' '94041' 'SW1Y 4RX' 'FIN-00045'
#  -7.12605090e+01 -1.22271532e+02 -1.21835193e+02  3.48561730e+01
#  -1.22421344e+02 -1.22280005e+02 -1.22087227e+02 -1.21973210e+02
#  -7.32525873e+01 -7.72451950e+01 -7.39968760e+01 -1.18380954e+02
#  -8.31678840e+01 -1.11643179e+02 -1.17200035e+02 -7.86778640e+01
#   1.16819980e+01 -1.18358376e+02 -1.22395785e+02 -7.39779465e+01
#   2.30758590e+00 -1.22679340e+02 -9.85629930e+01 -1.22062263e+02
#  -1.22500449e+02 -7.96042390e+01 -1.22053049e+02 -7.11927390e+01
#  -8.76355433e+01 -7.39920174e+01 -9.67905140e+01 -1.18473506e+02
#   1.33886100e+01 -1.18153136e+02  1.75274658e+02  1.24972454e+01
#  -1.22286493e+02 -1.21877636e+02 -1.22531566e+02 -1.21920717e+02
#  -7.37239990e+01]

# %% [markdown]
# From the above result we deduce the following:
#  * we don't need the columns which only have IDs in our ML model: acquisition_id, relationship_object_id, entity_id
#  * investigate more the columns which contain nan values: price_amount, price_currency_code, subject, first_investment_at, last_investment_at, investment_rounds, invested_companies, first_funding_at, last_funding_at, funding_rounds, funding_total_usd, zip_code
#  * the column 'Aquired' only contains the value _False_ => we don't need it
#  * the column 'entity_type'  only contains the value _Company_ => we don't need it
#  * the column 'closed\_at' contains only 4 unique values and nan => further investigate
#  * the columns 'latitude' and 'longitude' are not needed since we have information about location, such as contry, city and zip code
#  * the column 'relationships' contains irrelevant data for us => we drop it

# %%
# drop the columns which contains ids
df.drop(['acquisition_id', 'relationship_object_id', 'entity_id'], axis=1, inplace=True)

# drop the columns which we don't need
df.drop(['Aquired', 'entity_type', 'relationships', 'latitude', 'longitude'], axis=1, inplace=True)

# %%
# Summary statistics
df.describe(include="all")
# Out:
#         price_amount price_currency_code acquired_at    full_name  \
# count   1.995730e+06             7210949     7210707      7210715
# unique           NaN                   6        1414         8937
# top              NaN                 USD  2009-11-09  Erick Tseng
# freq             NaN             7104820      104242         8784
# mean    6.241055e+08                 NaN         NaN          NaN
# std     2.138176e+09                 NaN         NaN          NaN
# min     0.000000e+00                 NaN         NaN          NaN
# 25%     2.800000e+07                 NaN         NaN          NaN
# 50%     7.000000e+07                 NaN         NaN          NaN
# 75%     3.370000e+08                 NaN         NaN          NaN
# max     3.900000e+10                 NaN         NaN          NaN
#
#                  subject normalized_name category_code   status  founded_at  \
# count            5864970         7210978       7210800  7210978     7151879
# unique              2361             184            21        3          93
# top     Computer Science          google        search      ipo  1998-09-07
# freq             1198520         6474215       6475198  7202329     6474215
# mean                 NaN             NaN           NaN      NaN         NaN
# std                  NaN             NaN           NaN      NaN         NaN
# min                  NaN             NaN           NaN      NaN         NaN
# 25%                  NaN             NaN           NaN      NaN         NaN
# 50%                  NaN             NaN           NaN      NaN         NaN
# 75%                  NaN             NaN           NaN      NaN         NaN
# max                  NaN             NaN           NaN      NaN         NaN
#
#          closed_at       homepage_url country_code state_code_x  \
# count           25            7210591      7210978      7200134
# unique           4                181           23           21
# top     2009-12-23  http://google.com          USA           CA
# freq            10            6474215      7201046      6845495
# mean           NaN                NaN          NaN          NaN
# std            NaN                NaN          NaN          NaN
# min            NaN                NaN          NaN          NaN
# 25%            NaN                NaN          NaN          NaN
# 50%            NaN                NaN          NaN          NaN
# 75%            NaN                NaN          NaN          NaN
# max            NaN                NaN          NaN          NaN
#
#                city_x   region first_investment_at last_investment_at  \
# count         7204097  7210978             7187982            7187982
# unique            100       59                  62                 63
# top     Mountain View   SF Bay          2004-06-18         2013-05-01
# freq          6483703  6830840             6474215            6518695
# mean              NaN      NaN                 NaN                NaN
# std               NaN      NaN                 NaN                NaN
# min               NaN      NaN                 NaN                NaN
# 25%               NaN      NaN                 NaN                NaN
# 50%               NaN      NaN                 NaN                NaN
# 75%               NaN      NaN                 NaN                NaN
# max               NaN      NaN                 NaN                NaN
#
#         investment_rounds  invested_companies first_funding_at  \
# count        7.187982e+06        7.187982e+06          6704149
# unique                NaN                 NaN               68
# top                   NaN                 NaN       1998-08-01
# freq                  NaN                 NaN          6474215
# mean         2.787791e+01        2.493463e+01              NaN
# std          8.477186e+00        7.117151e+00              NaN
# min          1.000000e+00        1.000000e+00              NaN
# 25%          2.900000e+01        2.600000e+01              NaN
# 50%          2.900000e+01        2.600000e+01              NaN
# 75%          2.900000e+01        2.600000e+01              NaN
# max          8.900000e+01        7.300000e+01              NaN
#
#        last_funding_at  funding_rounds  funding_total_usd   description_y  \
# count          6704149    6.704149e+06       6.704113e+06         6994072
# unique              76             NaN                NaN             201
# top         1999-06-07             NaN                NaN  Google Seattle
# freq           6474215             NaN                NaN          193260
# mean               NaN    2.018723e+00       3.645655e+07             NaN
# std                NaN    5.745654e-01       1.529393e+08             NaN
# min                NaN    1.000000e+00       1.000000e+06             NaN
# 25%                NaN    2.000000e+00       2.510000e+07             NaN
# 50%                NaN    2.000000e+00       2.510000e+07             NaN
# 75%                NaN    2.000000e+00       2.510000e+07             NaN
# max                NaN    1.100000e+01       2.425700e+09             NaN
#
#          city_y zip_code
# count   7011070  6587020
# unique      208      305
# top     Seattle    98103
# freq     202671   193260
# mean        NaN      NaN
# std         NaN      NaN
# min         NaN      NaN
# 25%         NaN      NaN
# 50%         NaN      NaN
# 75%         NaN      NaN
# max         NaN      NaN

# %% [markdown]
# From the dataset statistics we notice in the 'count' row that the column 'closed_at' only has 25 values that are not NaN, thus, we drop the 'closed_at' column too.

# %%
print("Column 'closed_at' has {} cells containing nan values out of the total {} number of cells".format(
    get_nan_values_for_column(df, 'closed_at'),
    df.shape[0])
)
# Out:
# Column 'closed_at' has 7210953 cells containing nan values out of the total 7210978 number of cells

# %%
# drop 'closed_at' column
df.drop(['closed_at'], axis=1, inplace=True)

# %% [markdown]
# We want our Machine Learning model to predict the status ('ipo', 'operating' or 'closed') of companies. For this, we deduced that the relevant columns, from the dataframe, that could be used as features are: **subject, category_code, founded_at, funding_total_usd and city_y**, and the column **status** will represent the label of the data.

# %%
# drop irrelevant columns from the dataframe
df.drop(['price_amount', 'price_currency_code', 'acquired_at', 'full_name',
       'normalized_name','homepage_url', 'country_code', 'state_code_x', 'city_x', 'region',
       'first_investment_at', 'last_investment_at', 'investment_rounds',
       'invested_companies', 'first_funding_at', 'last_funding_at',
       'funding_rounds', 'description_y', 'zip_code'], 
        axis=1, inplace=True)

# %%
# Summary statistics for the reduced data frame
df.describe(include="all")
# Out:
#                  subject category_code   status  founded_at  \
# count            5864970       7210800  7210978     7151879
# unique              2361            21        3          93
# top     Computer Science        search      ipo  1998-09-07
# freq             1198520       6475198  7202329     6474215
# mean                 NaN           NaN      NaN         NaN
# std                  NaN           NaN      NaN         NaN
# min                  NaN           NaN      NaN         NaN
# 25%                  NaN           NaN      NaN         NaN
# 50%                  NaN           NaN      NaN         NaN
# 75%                  NaN           NaN      NaN         NaN
# max                  NaN           NaN      NaN         NaN
#
#         funding_total_usd   city_y
# count        6.704113e+06  7011070
# unique                NaN      208
# top                   NaN  Seattle
# freq                  NaN   202671
# mean         3.645655e+07      NaN
# std          1.529393e+08      NaN
# min          1.000000e+06      NaN
# 25%          2.510000e+07      NaN
# 50%          2.510000e+07      NaN
# 75%          2.510000e+07      NaN
# max          2.425700e+09      NaN

# %% [markdown]
# The total number of rows of the dataframe is 7210798, but if we inspect the _count_ rows of the statistics we notice that the other columns have less rows, e.g. the column subject only has 5864970. This means that the rest of the values, up to 7210798 are NaN  values.
#
# Next, we will delete the rows that contain NaN values, since those rows will impact negatively our model.

# %%
df = drop_nan_values_from_columns(df, ['subject','category_code','status', 'founded_at', 'funding_total_usd', 'city_y'])
df
# Out:
#                                                subject category_code  \
# 0                                     Computer Science        search
# 1                                     Computer Science        search
# 2                                     Computer Science        search
# 3                                     Computer Science        search
# 4                                     Computer Science        search
# ...                                                ...           ...
# 5296259  Finance, Economics, Organizational Psychology   advertising
# 5296260                         Industrial Engineering   advertising
# 5296261                             General Management   advertising
# 5296262                                 Communications   advertising
# 5296263                             Marketing Strategy   advertising
#
#             status  founded_at  funding_total_usd         city_y
# 0              ipo  1998-09-07         25100000.0  Mountain View
# 1              ipo  1998-09-07         25100000.0      Ann Arbor
# 2              ipo  1998-09-07         25100000.0        Atlanta
# 3              ipo  1998-09-07         25100000.0         Austin
# 4              ipo  1998-09-07         25100000.0        Boulder
# ...            ...         ...                ...            ...
# 5296259  operating  2006-11-01         53157047.0     Emeryville
# 5296260  operating  2006-11-01         53157047.0     Emeryville
# 5296261  operating  2006-11-01         53157047.0     Emeryville
# 5296262  operating  2006-11-01         53157047.0     Emeryville
# 5296263  operating  2006-11-01         53157047.0     Emeryville
#
# [5296264 rows x 6 columns]

# %%
# check to see if rows have nan values
are_columns_with_nan_values = False

for c in df.columns:
    if 0 != get_nan_values_for_column(df, c):
        are_columns_with_nan_values = True
        print(f"Column {c} still has NaN values")

if not are_columns_with_nan_values:
    print("No column has NaN values")
# Out:
# No column has NaN values

# %%
print(f"The maximum value from the 'funding_total_usd' column is " + str(df['funding_total_usd'].loc[df['funding_total_usd'].idxmax()]))
# Out:
# The maximum value from the 'funding_total_usd' column is 2425700000.0

# %% [markdown]
# Since the maximum value on the 'funding_total_usd' column is 2425700000 we can change its data type from float64 to float32. (we had a MemoryError when testing the pipeline and now we try to save space from where we can)

# %%
df['funding_total_usd'] = df['funding_total_usd'].astype(np.float32)

# %%
df.dtypes
# Out:
# subject              object
# category_code        object
# status               object
# founded_at           object
# funding_total_usd     int32
# city_y               object
# dtype: object

# %% [markdown]
# At the moment, the data in the dataframe there might be some ordering, i.e., rows belonging to the same subject or  category_code might be grouped together. We don't want our model to learn this ordering, so we need to make the dataset as random as possible. For this, we will shuffle the data inside the dataframe, i.e., we will randomize the order of the rows.

# %%
# Shuffle
df = df.take(np.random.permutation(len(df)))
df.reset_index(drop=True, inplace=True)
df.head(5)
# Out:
#                               subject category_code     status  founded_at  \
# 0                            Business        search        ipo  1998-09-07
# 1                          Journalism   advertising  operating  1987-10-14
# 2  Public Policy and Computer Science        search        ipo  1998-09-07
# 3              Mechanical Engineering        search        ipo  1998-09-07
# 4                   Economics, PreMed        search        ipo  1998-09-07
#
#    funding_total_usd          city_y
# 0           25100000       Trondheim
# 1           86400002        New York
# 2           25100000  St. Petersburg
# 3           25100000           Milan
# 4           25100000    Santa Monica

# %%
# due to the MemoryError received when running cross_val_score function, we create a smaller data frame that has
# 1000000 initial rows
df_smaller = df.take(np.random.permutation(len(df))[:1000000])
df_smaller.reset_index(drop=True, inplace=True)
df_smaller.head(5)
# Out:
#                                            subject category_code status  \
# 0                                 Computer Science        search    ipo
# 1                       Computer Science,Economics        search    ipo
# 2                                       psychology        search    ipo
# 3                                          Finance        search    ipo
# 4  Business Administration and Management, General        search    ipo
#
#    founded_at  funding_total_usd     city_y
# 0  1998-09-07         25100000.0    Atlanta
# 1  1998-09-07         25100000.0   Montreal
# 2  1998-09-07         25100000.0  Bangalore
# 3  1998-09-07         25100000.0  Bangalore
# 4  1998-09-07         25100000.0    Atlanta

# %%
# The features we want to select
numeric_features = ["funding_total_usd"]
nominal_features = ["subject", "category_code", "founded_at", "city_y"]

numeric_pipeline = Pipeline([
        ("selector", DataFrameSelector(numeric_features)),
        ("scaler", StandardScaler())
    ])

nominal_pipeline = Pipeline([
        ("selector", DataFrameSelector(nominal_features)), 
        ("binarizer", FeatureBinarizer([df[feature].unique() for feature in nominal_features]))])


pipeline = Pipeline([("union", FeatureUnion([("numeric_pipeline", numeric_pipeline), 
                                            ("nominal_pipeline", nominal_pipeline)])),
                              ("estimator", LogisticRegression(multi_class="multinomial", solver="newton-cg"))])

# %%
# get the labels
y = df_smaller['status'].values
y
# Out:
# array(['ipo', 'ipo', 'ipo', ..., 'ipo', 'ipo', 'ipo'], dtype=object)

# %%
# Stratified k-fold cross-validation
kf = StratifiedKFold(n_splits = 10)
np.mean(cross_val_score(pipeline, df_smaller, y, scoring="accuracy", cv=kf))
# Out:
# C:\Users\asabau\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:597: Warning: The least populated class in y has only 3 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# 0.9999930000299996
